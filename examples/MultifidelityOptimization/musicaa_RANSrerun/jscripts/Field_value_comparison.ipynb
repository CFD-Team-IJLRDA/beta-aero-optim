# %% [markdown]
# ## Original run

# %%
# Import librairies and classes
import numpy                    as np
import matplotlib.pyplot        as plt
import matplotlib.font_manager  as font_manager
import pandas                   as pd
import os

from mod_postProcessMusicaa     import postProcess
from matplotlib                 import colors
from mpl_toolkits.mplot3d       import Axes3D
from matplotlib.animation       import FuncAnimation
from matplotlib.colors          import LinearSegmentedColormap
from matplotlib.colors          import LogNorm
from matplotlib.colors          import TwoSlopeNorm
from IPython.display            import HTML

## Auto-reload of all changes in the imported scripts 
# %load_ext autoreload
# %autoreload 2

## Ensures inline plot 
# %matplotlib inline 

## Add option to toggle on/off raw code 
from IPython.display import HTML

HTML('''<script>
code_show=true; 
function code_toggle() {
 if (code_show){
 $('div.input').hide();
 } else {
 $('div.input').show();
 }
 code_show = !code_show
} 
$( document ).ready(code_toggle);
</script>
<form action="javascript:code_toggle()"><input type="submit" value="Click here to toggle on/off the raw code."></form>''')

## Initialization of class 

repo    = "../OGV_RANS_202501113_noShock"
pp_OGV_RANS = postProcess(rep=repo,bloc=[3,4,6,7], bloc_fst=[1,2,3,4,5,6,7,8,9], is_2D=True, ngh=5, is_RANS=True, model_RANS = 'SA' ,is_extended=True, is_stats=True, is_little_endian=True)
pp_OGV_RANS.init_postProcess()
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# *======
# Reading info.ini
# Done reading info.ini
# *======
# Reading info.ini
# Done reading info.ini
# *======
# Reading time.ini
# Done reading time.ini
# *======
# Reading param_blocks.ini
# Done reading param_blocks.ini
# *======
# Reading grid
# ngk is: 1
# Block #1, Mesh size: nx = 75, ny = 25, nz = 1
# ngk is: 1
# Block #2, Mesh size: nx = 75, ny = 50, nz = 1
# ngk is: 1
# Block #3, Mesh size: nx = 25, ny = 50, nz = 1
# ngk is: 1
# Block #4, Mesh size: nx = 100, ny = 50, nz = 1
# ngk is: 1
# Block #5, Mesh size: nx = 100, ny = 50, nz = 1
# ngk is: 1
# Block #6, Mesh size: nx = 100, ny = 50, nz = 1
# ngk is: 1
# Block #7, Mesh size: nx = 50, ny = 50, nz = 1
# ngk is: 1
# Block #8, Mesh size: nx = 75, ny = 50, nz = 1
# ngk is: 1
# Block #9, Mesh size: nx = 75, ny = 50, nz = 1
# *======
# Read snapshot characteristics
# Done reading snapshot characteristics
# *======
# Reading stats from block 1 in files ../OGV_RANS_202501113_noShock/stats1_bl1.bin hehe
# Reading stats from block 2 in files ../OGV_RANS_202501113_noShock/stats1_bl2.bin hehe
# Reading stats from block 3 in files ../OGV_RANS_202501113_noShock/stats1_bl3.bin hehe
# Reading stats from block 4 in files ../OGV_RANS_202501113_noShock/stats1_bl4.bin hehe
# Reading stats from block 5 in files ../OGV_RANS_202501113_noShock/stats1_bl5.bin hehe
# Reading stats from block 6 in files ../OGV_RANS_202501113_noShock/stats1_bl6.bin hehe
# Reading stats from block 7 in files ../OGV_RANS_202501113_noShock/stats1_bl7.bin hehe
# Reading stats from block 8 in files ../OGV_RANS_202501113_noShock/stats1_bl8.bin hehe
# Reading stats from block 9 in files ../OGV_RANS_202501113_noShock/stats1_bl9.bin hehe
# Reading stats from block 1 in files ../OGV_RANS_202501113_noShock/stats2_bl1.bin
# Reading stats from block 2 in files ../OGV_RANS_202501113_noShock/stats2_bl2.bin
# Reading stats from block 3 in files ../OGV_RANS_202501113_noShock/stats2_bl3.bin
# Reading stats from block 4 in files ../OGV_RANS_202501113_noShock/stats2_bl4.bin
# Reading stats from block 5 in files ../OGV_RANS_202501113_noShock/stats2_bl5.bin
# Reading stats from block 6 in files ../OGV_RANS_202501113_noShock/stats2_bl6.bin
# Reading stats from block 7 in files ../OGV_RANS_202501113_noShock/stats2_bl7.bin
# Reading stats from block 8 in files ../OGV_RANS_202501113_noShock/stats2_bl8.bin
# Reading stats from block 9 in files ../OGV_RANS_202501113_noShock/stats2_bl9.bin
# *======

# %% [markdown]
# ### Pressure

# %%
vmins = []
vmaxs = []

pres_global= {}

for i in range(1,10):
    pres_i = pp_OGV_RANS._stats1[i]['p']
    vmins.append(pres_i.min())
    vmaxs.append(pres_i.max())
    
vmin = min(vmins)
vmax = max(vmaxs)
    
for i in range(1,10):
    x_i=pp_OGV_RANS.x[i]
    y_i=pp_OGV_RANS.y[i]
    pres_i = pp_OGV_RANS._stats1[i]['p']
    pres_global[i] = pres_i
    plt.pcolormesh(x_i,y_i,pres_i,vmin=vmin,vmax=vmax)
    #contours = plt.contour(x_i,y_i,pres_i)
    
plt.colorbar(label='Pressure (Pa)')
plt.axvline(x=0, linestyle='--')
# Out:
# /tmp/ipykernel_352912/1445589359.py:19: UserWarning: The input coordinates to pcolormesh are interpreted as cell centers, but are not monotonically increasing or decreasing. This may lead to incorrectly calculated cell edges, in which case, please supply explicit cell edges to pcolormesh.
#   plt.pcolormesh(x_i,y_i,pres_i,vmin=vmin,vmax=vmax)

# %% [markdown]
# ### Velocity

# %%
vmins_V = []
vmaxs_V = []
vel_global={}

for i in range(1,10):
    V_i = (pp_OGV_RANS._stats1[i]['u']**2 + pp_OGV_RANS._stats1[i]['v']**2)**0.5
    vmins_V.append(V_i.min())
    vmaxs_V.append(V_i.max())
    
vmin_V = min(vmins_V)
vmax_V = max(vmaxs_V)
    
for i in range(1,10):
    x_i=pp_OGV_RANS.x[i]
    y_i=pp_OGV_RANS.y[i]
    V_i = (pp_OGV_RANS._stats1[i]['u']**2 + pp_OGV_RANS._stats1[i]['v']**2)**0.5
    vel_global[i]=V_i
    plt.pcolormesh(x_i,y_i,V_i,vmin=vmin_V,vmax=vmax_V)
    #contours = plt.contour(x_i,y_i,u_i)
    
plt.colorbar(label='Velocity field')
plt.axvline(x=0, linestyle='--')
# Out:
# /tmp/ipykernel_352912/2004731198.py:18: UserWarning: The input coordinates to pcolormesh are interpreted as cell centers, but are not monotonically increasing or decreasing. This may lead to incorrectly calculated cell edges, in which case, please supply explicit cell edges to pcolormesh.
#   plt.pcolormesh(x_i,y_i,V_i,vmin=vmin_V,vmax=vmax_V)

# %% [markdown]
# ## Extended run

# %%
## Initialization of class 

repo    = "../OGV_RANS_202501113_noShock_prolonged"
pp_OGV_RANS = postProcess(rep=repo,bloc=[3,4,6,7], bloc_fst=[1,2,3,4,5,6,7,8,9], is_2D=True, ngh=5, is_RANS=True, model_RANS = 'SA' ,is_extended=True, is_stats=True, is_little_endian=True)
pp_OGV_RANS.init_postProcess()
# Out:
# *======
# Reading info.ini
# Done reading info.ini
# *======
# Reading info.ini
# Done reading info.ini
# *======
# Reading time.ini
# Done reading time.ini
# *======
# Reading param_blocks.ini
# Done reading param_blocks.ini
# *======
# Reading grid
# ngk is: 1
# Block #1, Mesh size: nx = 75, ny = 25, nz = 1
# ngk is: 1
# Block #2, Mesh size: nx = 75, ny = 50, nz = 1
# ngk is: 1
# Block #3, Mesh size: nx = 25, ny = 50, nz = 1
# ngk is: 1
# Block #4, Mesh size: nx = 100, ny = 50, nz = 1
# ngk is: 1
# Block #5, Mesh size: nx = 100, ny = 50, nz = 1
# ngk is: 1
# Block #6, Mesh size: nx = 100, ny = 50, nz = 1
# ngk is: 1
# Block #7, Mesh size: nx = 50, ny = 50, nz = 1
# ngk is: 1
# Block #8, Mesh size: nx = 75, ny = 50, nz = 1
# ngk is: 1
# Block #9, Mesh size: nx = 75, ny = 50, nz = 1
# *======
# Read snapshot characteristics
# Done reading snapshot characteristics
# *======
# Reading stats from block 1 in files ../OGV_RANS_202501113_noShock_prolonged/stats1_bl1.bin hehe
# Reading stats from block 2 in files ../OGV_RANS_202501113_noShock_prolonged/stats1_bl2.bin hehe
# Reading stats from block 3 in files ../OGV_RANS_202501113_noShock_prolonged/stats1_bl3.bin hehe
# Reading stats from block 4 in files ../OGV_RANS_202501113_noShock_prolonged/stats1_bl4.bin hehe
# Reading stats from block 5 in files ../OGV_RANS_202501113_noShock_prolonged/stats1_bl5.bin hehe
# Reading stats from block 6 in files ../OGV_RANS_202501113_noShock_prolonged/stats1_bl6.bin hehe
# Reading stats from block 7 in files ../OGV_RANS_202501113_noShock_prolonged/stats1_bl7.bin hehe
# Reading stats from block 8 in files ../OGV_RANS_202501113_noShock_prolonged/stats1_bl8.bin hehe
# Reading stats from block 9 in files ../OGV_RANS_202501113_noShock_prolonged/stats1_bl9.bin hehe
# Reading stats from block 1 in files ../OGV_RANS_202501113_noShock_prolonged/stats2_bl1.bin
# Reading stats from block 2 in files ../OGV_RANS_202501113_noShock_prolonged/stats2_bl2.bin
# Reading stats from block 3 in files ../OGV_RANS_202501113_noShock_prolonged/stats2_bl3.bin
# Reading stats from block 4 in files ../OGV_RANS_202501113_noShock_prolonged/stats2_bl4.bin
# Reading stats from block 5 in files ../OGV_RANS_202501113_noShock_prolonged/stats2_bl5.bin
# Reading stats from block 6 in files ../OGV_RANS_202501113_noShock_prolonged/stats2_bl6.bin
# Reading stats from block 7 in files ../OGV_RANS_202501113_noShock_prolonged/stats2_bl7.bin
# Reading stats from block 8 in files ../OGV_RANS_202501113_noShock_prolonged/stats2_bl8.bin
# Reading stats from block 9 in files ../OGV_RANS_202501113_noShock_prolonged/stats2_bl9.bin
# *======

# %% [markdown]
# ### Pressure

# %%
vmins = []
vmaxs = []

pres_global_extended= {}

for i in range(1,10):
    pres_i = pp_OGV_RANS._stats1[i]['p']
    vmins.append(pres_i.min())
    vmaxs.append(pres_i.max())
    
vmin = min(vmins)
vmax = max(vmaxs)
    
for i in range(1,10):
    x_i=pp_OGV_RANS.x[i]
    y_i=pp_OGV_RANS.y[i]
    pres_i = pp_OGV_RANS._stats1[i]['p']
    pres_global_extended[i] = pres_i
    plt.pcolormesh(x_i,y_i,pres_i,vmin=vmin,vmax=vmax)
    #contours = plt.contour(x_i,y_i,pres_i)
    
plt.colorbar(label='Pressure (Pa)')
plt.axvline(x=0, linestyle='--')
# Out:
# /tmp/ipykernel_352912/2500811506.py:19: UserWarning: The input coordinates to pcolormesh are interpreted as cell centers, but are not monotonically increasing or decreasing. This may lead to incorrectly calculated cell edges, in which case, please supply explicit cell edges to pcolormesh.
#   plt.pcolormesh(x_i,y_i,pres_i,vmin=vmin,vmax=vmax)

# %% [markdown]
# ### Velocity

# %%
vmins_V = []
vmaxs_V = []
vel_global_extended={}

for i in range(1,10):
    V_i = (pp_OGV_RANS._stats1[i]['u']**2 + pp_OGV_RANS._stats1[i]['v']**2)**0.5
    vmins_V.append(V_i.min())
    vmaxs_V.append(V_i.max())
    
vmin_V = min(vmins_V)
vmax_V = max(vmaxs_V)
    
for i in range(1,10):
    x_i=pp_OGV_RANS.x[i]
    y_i=pp_OGV_RANS.y[i]
    V_i = (pp_OGV_RANS._stats1[i]['u']**2 + pp_OGV_RANS._stats1[i]['v']**2)**0.5
    vel_global_extended[i]=V_i
    plt.pcolormesh(x_i,y_i,V_i,vmin=vmin_V,vmax=vmax_V)
    #contours = plt.contour(x_i,y_i,u_i)
    
plt.colorbar(label='Velocity field')
plt.axvline(x=0, linestyle='--')
# Out:
# /tmp/ipykernel_352912/4092274555.py:18: UserWarning: The input coordinates to pcolormesh are interpreted as cell centers, but are not monotonically increasing or decreasing. This may lead to incorrectly calculated cell edges, in which case, please supply explicit cell edges to pcolormesh.
#   plt.pcolormesh(x_i,y_i,V_i,vmin=vmin_V,vmax=vmax_V)

# %% [markdown]
# ## Result comparison

# %% [markdown]
# ### Pressure field difference

# %%
print(np.shape(pres_global[1]))
print(np.shape(pres_global_extended[1]))
# Out:
# (75, 25)
# (75, 25)

# %%
vmins = []
vmaxs = []

for i in range(1,10):
    pres_diff_i = abs(pres_global[i] - pres_global_extended[i])
    vmins.append(pres_diff_i.min())
    vmaxs.append(pres_diff_i.max())
    
vmin = min(vmins)
vmax = max(vmaxs)
    
for i in range(1,10):
    x_i=pp_OGV_RANS.x[i]
    y_i=pp_OGV_RANS.y[i]
    pres_diff_i = abs(pres_global[i] - pres_global_extended[i])
    plt.pcolormesh(x_i,y_i,pres_diff_i,vmin=0,vmax=0.3)
    #contours = plt.contour(x_i,y_i,pres_i)
    
plt.colorbar(label='Pressure difference (Pa)')
plt.axvline(x=0, linestyle='--')
plt.title('Pressure field difference between 0.5M and 1M iterations')
# Out:
# /tmp/ipykernel_352912/2607944745.py:16: UserWarning: The input coordinates to pcolormesh are interpreted as cell centers, but are not monotonically increasing or decreasing. This may lead to incorrectly calculated cell edges, in which case, please supply explicit cell edges to pcolormesh.
#   plt.pcolormesh(x_i,y_i,pres_diff_i,vmin=0,vmax=0.3)
# Text(0.5, 1.0, 'Pressure field difference between 0.5M and 1M iterations')

# %% [markdown]
# ### Velocity field difference

# %%
vmins = []
vmaxs = []

for i in range(1,10):
    vel_diff_i = abs(vel_global[i] - vel_global_extended[i])
    vmins.append(vel_diff_i.min())
    vmaxs.append(vel_diff_i.max())
    
vmin = min(vmins)
vmax = max(vmaxs)
    
for i in range(1,10):
    x_i=pp_OGV_RANS.x[i]
    y_i=pp_OGV_RANS.y[i]
    vel_diff_i = abs(vel_global[i] - vel_global_extended[i])
    plt.pcolormesh(x_i,y_i,vel_diff_i,vmin=0,vmax=0.05)
    
plt.colorbar(label='Velocity difference (m/s)')
plt.axvline(x=0, linestyle='--')
plt.title('Velocity field difference between 0.5M and 1M iterations')
# Out:
# /tmp/ipykernel_352912/3475938908.py:16: UserWarning: The input coordinates to pcolormesh are interpreted as cell centers, but are not monotonically increasing or decreasing. This may lead to incorrectly calculated cell edges, in which case, please supply explicit cell edges to pcolormesh.
#   plt.pcolormesh(x_i,y_i,vel_diff_i,vmin=0,vmax=0.05)
# Text(0.5, 1.0, 'Velocity field difference between 0.5M and 1M iterations')
